# %%
from pathlib import Path

import pandas as pd

# %%
def load_data(filename: str) -> pd.DataFrame:
    p = Path(f"./data/{filename}")
    assert p.exists()

    df = pd.read_csv(filepath_or_buffer=p)

    df["Genre"] = df.Genre.astype("category").cat.codes
    df["Episode_Sentiment"] = df.Episode_Sentiment.astype("category").cat.codes
    df["Publication_Day"] = df.Publication_Day.astype("category").cat.codes
    df["Publication_Time"] = df.Publication_Time.astype("category").cat.codes
    df["Episode_Title"] = df.Episode_Title.astype("category").cat.codes
    df["Podcast_Name"] = df.Podcast_Name.astype("category").cat.codes

    return df


train_df = load_data("train.csv")

# %%
train_df
# Out:
#             id  Podcast_Name  Episode_Title  Episode_Length_minutes  Genre  \
# 0            0            34             98                     NaN      9
# 1            1            24             19                  119.80      1
# 2            2            40              8                   73.90      2
# 3            3            10             40                   67.17      8
# 4            4            31             85                  110.51      3
# ...        ...           ...            ...                     ...    ...
# 749995  749995            26             18                   75.66      2
# 749996  749996             2             14                   75.75      0
# 749997  749997            28             47                   30.98      4
# 749998  749998            41             42                  108.98      4
# 749999  749999            38             99                   24.10      7
#
#         Host_Popularity_percentage  Publication_Day  Publication_Time  \
# 0                            74.81                4                 3
# 1                            66.95                2                 0
# 2                            69.97                5                 1
# 3                            57.22                1                 2
# 4                            80.07                1                 0
# ...                            ...              ...               ...
# 749995                       69.36                2                 2
# 749996                       35.21                2                 3
# 749997                       78.58                4                 2
# 749998                       45.39                4                 2
# 749999                       22.45                2                 3
#
#         Guest_Popularity_percentage  Number_of_Ads  Episode_Sentiment  \
# 0                               NaN            0.0                  2
# 1                             75.95            2.0                  0
# 2                              8.97            0.0                  0
# 3                             78.70            2.0                  2
# 4                             58.68            3.0                  1
# ...                             ...            ...                ...
# 749995                          NaN            0.0                  0
# 749996                          NaN            2.0                  1
# 749997                        84.89            0.0                  0
# 749998                        93.27            0.0                  0
# 749999                        36.72            0.0                  1
#
#         Listening_Time_minutes
# 0                     31.41998
# 1                     88.01241
# 2                     44.92531
# 3                     46.27824
# 4                     75.61031
# ...                        ...
# 749995                56.87058
# 749996                45.46242
# 749997                15.26000
# 749998               100.72939
# 749999                11.94439
#
# [750000 rows x 12 columns]

# %%
train_df.dropna()
# Out:
#             id  Podcast_Name  Episode_Title  Episode_Length_minutes  Genre  \
# 1            1            24             19                  119.80      1
# 2            2            40              8                   73.90      2
# 3            3            10             40                   67.17      8
# 4            4            31             85                  110.51      3
# 6            6             6             42                   69.83      9
# ...        ...           ...            ...                     ...    ...
# 749992  749992            12             73                   48.67      4
# 749993  749993            41             82                   23.52      4
# 749997  749997            28             47                   30.98      4
# 749998  749998            41             42                  108.98      4
# 749999  749999            38             99                   24.10      7
#
#         Host_Popularity_percentage  Publication_Day  Publication_Time  \
# 1                            66.95                2                 0
# 2                            69.97                5                 1
# 3                            57.22                1                 2
# 4                            80.07                1                 0
# 6                            35.82                3                 3
# ...                            ...              ...               ...
# 749992                       88.62                6                 1
# 749993                       38.14                5                 1
# 749997                       78.58                4                 2
# 749998                       45.39                4                 2
# 749999                       22.45                2                 3
#
#         Guest_Popularity_percentage  Number_of_Ads  Episode_Sentiment  \
# 1                             75.95            2.0                  0
# 2                              8.97            0.0                  0
# 3                             78.70            2.0                  2
# 4                             58.68            3.0                  1
# 6                             39.02            0.0                  1
# ...                             ...            ...                ...
# 749992                        25.65            3.0                  2
# 749993                        86.17            0.0                  1
# 749997                        84.89            0.0                  0
# 749998                        93.27            0.0                  0
# 749999                        36.72            0.0                  1
#
#         Listening_Time_minutes
# 1                     88.01241
# 2                     44.92531
# 3                     46.27824
# 4                     75.61031
# 6                     64.75024
# ...                        ...
# 749992                42.08465
# 749993                19.71374
# 749997                15.26000
# 749998               100.72939
# 749999                11.94439
#
# [539048 rows x 12 columns]
